# %%
# 1. Add 'orange' to the end of ['apple', 'banana', 'mango'].
a = ['apple', 'banana', 'mango']
a.append("orange")
print(a)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
# 2. Insert 'kiwi' at index 1 in ['apple', 'banana', 'mango'].
a = ['apple', 'banana', 'mango']
a.insert(1,"kiwi")
print(a)
# Out:
# ['apple', 'kiwi', 'banana', 'mango']

# %%
# 3. Remove 'banana' from ['apple', 'banana', 'mango'].
a = ['apple', 'banana', 'mango']
a.remove("banana")
print(a)
# Out:
# ['apple', 'mango']

# %%
# 4. Remove the last item using pop().
a = ['apple', 'banana', 'mango']
a.pop()
print(a)
# Out:
# ['apple', 'banana']

# %%
# 5. Find the total number of students in ['Rahul', 'Priya', 'Aman', 'Neha'].
a = ['Rahul', 'Priya', 'Aman', 'Neha']
print(len(a))
# Out:
# 4

# %%
# 6. Count how many times 10 appears in [10, 20, 10, 30, 10, 40].
a = [10, 20, 10, 30, 10, 40]
print(a.count(10))
# Out:
# 3

# %%
# 7. Find the index of 'Bangalore' in a city list.
cities = ["Bangalore" , "Mysore" , "Mandya" , "Maddur"]
print(cities.index("Bangalore"))
# Out:
# 0

# %%
# 8. Reverse the list [1, 2, 3, 4, 5].
a = [1, 2, 3, 4, 5]
a.reverse()
print(a)
# Out:
# [5, 4, 3, 2, 1]

# %%
# 9. Sort the list [45, 10, 99, 23, 1].
a = [45, 10, 99, 23, 1]
a.sort()
print(a)
# Out:
# [1, 10, 23, 45, 99]

# %%
# 10. Clear all items from a fruit list.
fruit = ['apple' , 'banana' , 'kiwi']
fruit.clear()
print(fruit)
# Out:
# []

# %%
# 11. Combine two lists using extend().
n1 = [1,2,3]
n2 = [4,5,6]
n1.extend(n2)
print(n1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 12. Create a backup copy of a list using copy().
fruit = ['apple' , 'banana' , 'kiwi']
copy = fruit.copy()
print(copy)
# Out:
# ['apple', 'banana', 'kiwi']

# %%
# 13. Add multiple fruits using extend().
fruit = ['apple' , 'banana' , 'kiwi']
fruit.extend(["orange" , "melons" , "mangoes"])
print(fruit)
# Out:
# ['apple', 'banana', 'kiwi', 'orange', 'melons', 'mangoes']

# %%
# 14. Remove an item by index using pop(index).
fruit = ['apple' , 'banana' , 'kiwi']
fruit.pop(1)
print(fruit)
# Out:
# ['apple', 'kiwi']

# %%
# 15. Find the largest number using a built-in function.
n = [2838,5,12,90,543]
n.sort()
print(n[-1])
# Out:
# 2838

# %%
# 16. Predict the output of append() when adding a list inside another list.
fruit = ['apple' , 'banana' , 'kiwi']
fruit.append(["banana" , "tomato"])
print(fruit)
# Out:
# ['apple', 'banana', 'kiwi', ['banana', 'tomato']]

# %%
# 17. Predict the output of pop() and the modified list.
fruit = ['apple' , 'banana' , 'kiwi']
popped = fruit.pop()
print(popped)
print(fruit)
# Out:
# kiwi
# ['apple', 'banana']

# %%
# 18. Find the second largest number in a list.
n = [2838,5,12,90,543]
n.sort()
print(n[-2])
# Out:
# 543

# %%
# 19. Remove duplicate values from a list.
a = [1,3,2,2,1,4,5,6,5,4,]
print(set(a))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# 20. Create a mini Student Management System using list methods.
students = []
name = ""
while name != "exit":
    name = input("enter the students name . type exit to exit . type print to show the list")
    if name == "print":
        print(students)
    else:
        students.append(name)
# Out:
# enter the students name . type exit to exit . type print to show the list asdf
# enter the students name . type exit to exit . type print to show the list jhgfjgh
# enter the students name . type exit to exit . type print to show the list print
# ['asdf', 'jhgfjgh']
# enter the students name . type exit to exit . type print to show the list exit
