# %%
import requests

url = "http://api.open-notify.org/iss-now.json"

response = requests.get(url)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'timestamp': 1780995759, 'message': 'success', 'iss_position': {'latitude': '-25.4206', 'longitude': '-76.9260'}}

# %%
import requests

url = "http://api.open-notify.org/iss-now.json"

response = requests.get(url)

data = response.json()

latitude = data["iss_position"]["latitude"]
longitude = data["iss_position"]["longitude"]

print("Latitude:", latitude)
print("Longitude:", longitude)
# Out:
# Latitude: -25.0683
# Longitude: -76.5901

# %%
timestamp = data["timestamp"]

print("Timestamp:", timestamp)
# Out:
# Timestamp: 1780995767

# %%
from datetime import datetime

human_time = datetime.fromtimestamp(timestamp)

print("Human Readable Time:", human_time)
# Out:
# Human Readable Time: 2026-06-09 14:32:47

# %%
iss_data = response.json()

print(type(iss_data))
# Out:
# <class 'dict'>

# %%
for key in data.keys():
    print(key)
# Out:
# timestamp
# message
# iss_position

# %%
for key in data["iss_position"].keys():
    print(key)
# Out:
# latitude
# longitude
