# %%
# 1. Create a function to add two numbers.
def fun(a,b):
    print(a+b)
fun(3,8)
# Out:
# 11

# %%
# 2. Create a function to find the square of a number.
def fun(a):
    print(a*a)
fun(3)
# Out:
# 9

# %%
# 3. Create a function to check whether a number is even or odd.
def fun(a):
    if a%2 ==0 :
        print("even")
    else:
        print("odd")
fun(7)
# Out:
# odd

# %%
# 4. Create a function to find the maximum of two numbers.
def fun(a):
    if a%2 ==0 :
        print("even")
    else:
        print("odd")
fun(7)

# %%
# 5. Create a function to calculate the factorial of a number.
# 6. Create a function to count vowels in a string.
# 7. Create a function to reverse a string.
# 8. Create a function to check whether a string is palindrome or not.
# 9. Create a function to find the sum of all elements in a list.
# 10. Create a function to find the largest element in a list.
# 11. Create a lambda function to add two numbers.
# 12. Create a lambda function to find square of a number.
# 13. Create a lambda function to find cube of a number.
# 14. Create a lambda function to check even numbers.
# 15. Create a lambda function to find maximum between two numbers.
# 16. Use lambda with map() to square all list elements.
# 17. Use lambda with filter() to get even numbers from a list.
# 18. Use lambda with filter() to get odd numbers from a list.
# 19. Use lambda with sorted() to sort tuples by second value.
# 20. Use lambda with reduce() to find multiplication of list elements.
# 21. Use zip() to combine two lists into pairs.
# 22. Use zip() to combine names and marks lists.
# 23. Use zip() to create a dictionary from two lists.
# 24. Use zip() to print student names with grades.
# 25. Use zip() to add elements of two lists.
# 26. Use zip() to find maximum values from two lists pairwise.
# 27. Use zip() to iterate over three lists together.
# 28. Use zip() to unzip a list of tuples.
# 29. Use zip() to combine countries and capitals.
# 30. Use zip() to compare elements of two lists.
# 31. Use enumerate() to print index and value of a list.
# 32. Use enumerate() with a string.
# 33. Use enumerate() starting index from 1.
# 34. Use enumerate() to find positions of even numbers.
# 35. Use enumerate() to print words with index.
# 36. Use enumerate() to count characters in a string.
# 37. Use enumerate() to print index of vowels.
# 38. Use enumerate() with tuple data.
# 39. Use enumerate() to print student names with roll numbers.
# 40. Use enumerate() to reverse print indexes and values.
# 41. Create a function using *args to find sum of numbers.
# 42. Create a function using *args to find maximum number.
# 43. Create a function using *args to multiply numbers.
# 44. Create a function using *args to count total arguments passed.
# 45. Create a function using **kwargs to print student details.
# 46. Create a function using **kwargs to print employee information.
# 47. Create a function using **kwargs to display product details.
# 48. Create a function using both *args and **kwargs.
# 49. Create a calculator function using *args.
# 50. Create a menu function using **kwargs for food items and prices.
